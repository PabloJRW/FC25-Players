# %%
import os
import pandas as pd

# %%
FILE_PATH = os.path.join('..','extraction','raw_data','fc25players_10_21_2024.csv')
df = pd.read_csv(FILE_PATH)
df
# Out:
#        id_player first_name           last_name     common_name  \
# 0         231747     Kylian              Mbappé             NaN
# 1         231866    Rodrigo  Hernández Cascante           Rodri
# 2         241667     Aitana       Bonmatí Conca  Aitana Bonmatí
# 3         239085     Erling             Haaland             NaN
# 4         252371       Jude          Bellingham             NaN
# ...          ...        ...                 ...             ...
# 17365     259649     Engson               Singh             NaN
# 17366      73840    Ousmane               Sylla             NaN
# 17367     269015       Feng                 Wei        Wei Feng
# 17368      71458     Hui Do                 Won      Won Hui Do
# 17369     269541     Yuhang                  Wu       Wu Yuhang
#
#                                               avatar_url  \
# 0      https://ratings-images-prod.pulse.ea.com/FC25/...
# 1      https://ratings-images-prod.pulse.ea.com/FC25/...
# 2      https://ratings-images-prod.pulse.ea.com/FC25/...
# 3      https://ratings-images-prod.pulse.ea.com/FC25/...
# 4      https://ratings-images-prod.pulse.ea.com/FC25/...
# ...                                                  ...
# 17365  https://ratings-images-prod.pulse.ea.com/FC25/...
# 17366  https://ratings-images-prod.pulse.ea.com/FC25/...
# 17367  https://ratings-images-prod.pulse.ea.com/FC25/...
# 17368  https://ratings-images-prod.pulse.ea.com/FC25/...
# 17369  https://ratings-images-prod.pulse.ea.com/FC25/...
#
#                                               shield_url  gender_id  height  \
# 0      https://ratings-images-prod.pulse.ea.com/FC25/...          0     182
# 1      https://ratings-images-prod.pulse.ea.com/FC25/...          0     191
# 2      https://ratings-images-prod.pulse.ea.com/FC25/...          1     162
# 3      https://ratings-images-prod.pulse.ea.com/FC25/...          0     195
# 4      https://ratings-images-prod.pulse.ea.com/FC25/...          0     186
# ...                                                  ...        ...     ...
# 17365  https://ratings-images-prod.pulse.ea.com/FC25/...          0     169
# 17366  https://ratings-images-prod.pulse.ea.com/FC25/...          0     176
# 17367  https://ratings-images-prod.pulse.ea.com/FC25/...          0     181
# 17368  https://ratings-images-prod.pulse.ea.com/FC25/...          0     187
# 17369  https://ratings-images-prod.pulse.ea.com/FC25/...          0     182
#
#        weight  id_nationality  ... diff_positioning diff_reactions diff_sho  \
# 0          75              18  ...                0              0        0
# 1          82              45  ...                1              4        7
# 2          53              45  ...                0              0        2
# 3          94              36  ...                0              0       -1
# 4          75              14  ...               12              5       12
# ...       ...             ...  ...              ...            ...      ...
# 17365      62             159  ...                0              0        0
# 17366      74             136  ...                0              0        0
# 17367      69             155  ...                0              0        0
# 17368      71             167  ...                0              0        0
# 17369      75             155  ...                0              0        0
#
#       diff_shortPassing diff_shotPower diff_slidingTackle diff_sprintSpeed  \
# 0                     0              0                  0                0
# 1                     4              1                  4                4
# 2                     0             10                  0                0
# 3                     0              0                  0                0
# 4                     2              7                  0                5
# ...                 ...            ...                ...              ...
# 17365                 0              0                  0              -16
# 17366                 0              0                  0                0
# 17367                 0              0                  0                0
# 17368                 0              0                  0                0
# 17369                 0              0                  0                0
#
#        diff_standingTackle diff_vision diff_volleys
# 0                        0           0            0
# 1                        0           2           12
# 2                        0           0            8
# 3                        0           0            0
# 4                        0           6            6
# ...                    ...         ...          ...
# 17365                    0           0            0
# 17366                    0           0            0
# 17367                    0           0            0
# 17368                    0           0            0
# 17369                    0           0            0
#
# [17370 rows x 105 columns]

# %%
players_cols = ["id_player","first_name","last_name","common_name","avatar_url","shield_url","gender_id","height","weight","birthdate"]
players_df = df[players_cols]
players_df.set_index("id_player", inplace=True)
players_df[:3]
# Out:
#           first_name           last_name     common_name  \
# id_player
# 231747        Kylian              Mbappé             NaN
# 231866       Rodrigo  Hernández Cascante           Rodri
# 241667        Aitana       Bonmatí Conca  Aitana Bonmatí
#
#                                                   avatar_url  \
# id_player
# 231747     https://ratings-images-prod.pulse.ea.com/FC25/...
# 231866     https://ratings-images-prod.pulse.ea.com/FC25/...
# 241667     https://ratings-images-prod.pulse.ea.com/FC25/...
#
#                                                   shield_url  gender_id  \
# id_player
# 231747     https://ratings-images-prod.pulse.ea.com/FC25/...          0
# 231866     https://ratings-images-prod.pulse.ea.com/FC25/...          0
# 241667     https://ratings-images-prod.pulse.ea.com/FC25/...          1
#
#            height  weight               birthdate
# id_player
# 231747        182      75  12/20/1998 12:00:00 AM
# 231866        191      82   6/22/1996 12:00:00 AM
# 241667        162      53   1/18/1998 12:00:00 AM

# %%
player_technical_cols = ["id_player","preferred_foot",'weak_foot_ability', 'skill_moves', "overall_rating"]
player_technical_df = df[player_technical_cols].copy()
player_technical_df.set_index("id_player", inplace=True)
player_technical_df[:3]
# Out:
#            preferred_foot  weak_foot_ability  skill_moves  overall_rating
# id_player
# 231747                  1                  4            5              91
# 231866                  1                  4            3              91
# 241667                  1                  5            4              91

# %%
player_abilities_cols = ["id_player", "player_abilities"]
player_abilities_df = df[player_abilities_cols].copy()
player_abilities_df['player_abilities'] = player_abilities_df['player_abilities'].str.split(', ')
player_abilities_df = player_abilities_df.explode('player_abilities').reset_index(drop=True)
player_abilities_df.set_index("id_player", inplace=True)
player_abilities_df
# Out:
#           player_abilities
# id_player
# 231747        Finesse Shot
# 231747               Rapid
# 231747               Flair
# 231747             Trivela
# 231747           Acrobatic
# ...                    ...
# 259649                 NaN
# 73840                  NaN
# 269015                 NaN
# 71458                  NaN
# 269541                 NaN
#
# [25316 rows x 1 columns]

# %%
team_cols = ["id_player","team","league_name","team_image_url"]
team_df = df[team_cols].copy()
team_df.set_index("id_player", inplace=True)
team_df[:3]
# Out:
#                       team       league_name  \
# id_player
# 231747         Real Madrid  LALIGA EA SPORTS
# 231866     Manchester City    Premier League
# 241667        FC Barcelona            Liga F
#
#                                               team_image_url
# id_player
# 231747     https://images.ctfassets.net/rs6bgs1g8dbr/3X9L...
# 231866     https://images.ctfassets.net/rs6bgs1g8dbr/5Gnv...
# 241667     https://images.ctfassets.net/rs6bgs1g8dbr/6iI4...

# %%
nationality_cols = ["id_player","id_nationality","nationality","nationality_url"]
nationality_df = df[nationality_cols].copy()
nationality_df.set_index("id_player", inplace=True)
nationality_df[:3]
# Out:
#            id_nationality nationality  \
# id_player
# 231747                 18      France
# 231866                 45       Spain
# 241667                 45       Spain
#
#                                              nationality_url
# id_player
# 231747     https://images.ctfassets.net/rs6bgs1g8dbr/5Il3...
# 231866     https://images.ctfassets.net/rs6bgs1g8dbr/7k3V...
# 241667     https://images.ctfassets.net/rs6bgs1g8dbr/7k3V...

# %%
stats_cols = df.filter(regex='^stat_').columns.tolist()
stats_temp = df[["id_player"]+stats_cols].copy()
stats_melted = pd.melt(stats_temp, id_vars=['id_player'], var_name='stats', value_name='stats_point')
#stats_melted = stats_melted['stats'].str.replace('stat_', '')
stats_df = stats_melted
stats_df
# Out:
# 0         acceleration
# 1         acceleration
# 2         acceleration
# 3         acceleration
# 4         acceleration
#               ...
# 694795         volleys
# 694796         volleys
# 694797         volleys
# 694798         volleys
# 694799         volleys
# Name: stats, Length: 694800, dtype: object

# %%
diff_stats_cols = df.filter(regex='^diff_').columns.tolist()
diff_stats_df = df[["id_player"]+diff_stats_cols].copy()
diff_stats_df.set_index("id_player", inplace=True)
diff_stats_df[:3]
# Out:
#            diff_acceleration  diff_agility  diff_jumping  diff_stamina  \
# id_player
# 231747                     0             0             0             0
# 231866                    11             1             3             2
# 241667                     0             0             0             2
#
#            diff_strength  diff_aggression  diff_balance  diff_ballControl  \
# id_player
# 231747                 0                0             0                 0
# 231866                 0                2             3                 2
# 241667                 0                4             0                 0
#
#            diff_composure  diff_crossing  ...  diff_positioning  \
# id_player                                 ...
# 231747                  0              0  ...                 0
# 231866                  9             13  ...                 1
# 241667                  0              7  ...                 0
#
#            diff_reactions  diff_sho  diff_shortPassing  diff_shotPower  \
# id_player
# 231747                  0         0                  0               0
# 231866                  4         7                  4               1
# 241667                  0         2                  0              10
#
#            diff_slidingTackle  diff_sprintSpeed  diff_standingTackle  \
# id_player
# 231747                      0                 0                    0
# 231866                      4                 4                    0
# 241667                      0                 0                    0
#
#            diff_vision  diff_volleys
# id_player
# 231747               0             0
# 231866               2            12
# 241667               0             8
#
# [3 rows x 40 columns]

# %%
position_cols = ["id_player","position","position_short_label","position_type","alternate_positions"]
position_df = df[position_cols].copy()
position_df.set_index("id_player", inplace=True)
position_df[:3]
# Out:
#                               position position_short_label position_type  \
# id_player
# 231747                         Striker                   ST        Attack
# 231866     Center Defensive Midfielder                  CDM    Midfielder
# 241667               Center Midfielder                   CM    Midfielder
#
#           alternate_positions
# id_player
# 231747                     LW
# 231866                     CM
# 241667                    CAM

# %%
all_columns = players_cols + nationality_cols + stats_cols + diff_stats_cols + team_cols + position_cols + player_abilities_cols + player_technical_cols + player_abilities_cols
missing_cols = [col for col in df.columns if col not in all_columns]
print(missing_cols)
# Out:
# []

# %%
df.sort_values(by="id_player", ascending=True)
# Out:
#        id_player      first_name          last_name        common_name  \
# 5616       18115    Rúben Miguel   Santos Fernandes    Rúben Fernandes
# 14153      19541           Glenn             Morris                NaN
# 66         20801      C. Ronaldo  dos Santos Aveiro  Cristiano Ronaldo
# 9365       23823         Andreas          Johansson                NaN
# 1691       24630     José Manuel         Reina Páez         Pepe Reina
# ...          ...             ...                ...                ...
# 8045      279930  Felipe Augusto           da Silva     Felipe Augusto
# 7141      279933            Anni        Hartikainen                NaN
# 11907     279934             Ian           Subiabre                NaN
# 17337     279941           Tommy              Silva                NaN
# 9419      279948            Koen            Kostons                NaN
#
#                                               avatar_url  \
# 5616   https://ratings-images-prod.pulse.ea.com/FC25/...
# 14153  https://ratings-images-prod.pulse.ea.com/FC25/...
# 66     https://ratings-images-prod.pulse.ea.com/FC25/...
# 9365   https://ratings-images-prod.pulse.ea.com/FC25/...
# 1691   https://ratings-images-prod.pulse.ea.com/FC25/...
# ...                                                  ...
# 8045   https://ratings-images-prod.pulse.ea.com/FC25/...
# 7141   https://ratings-images-prod.pulse.ea.com/FC25/...
# 11907  https://ratings-images-prod.pulse.ea.com/FC25/...
# 17337  https://ratings-images-prod.pulse.ea.com/FC25/...
# 9419   https://ratings-images-prod.pulse.ea.com/FC25/...
#
#                                               shield_url  gender_id  height  \
# 5616   https://ratings-images-prod.pulse.ea.com/FC25/...          0     187
# 14153  https://ratings-images-prod.pulse.ea.com/FC25/...          0     183
# 66     https://ratings-images-prod.pulse.ea.com/FC25/...          0     187
# 9365   https://ratings-images-prod.pulse.ea.com/FC25/...          0     184
# 1691   https://ratings-images-prod.pulse.ea.com/FC25/...          0     188
# ...                                                  ...        ...     ...
# 8045   https://ratings-images-prod.pulse.ea.com/FC25/...          0     187
# 7141   https://ratings-images-prod.pulse.ea.com/FC25/...          1     167
# 11907  https://ratings-images-prod.pulse.ea.com/FC25/...          0     171
# 17337  https://ratings-images-prod.pulse.ea.com/FC25/...          0     178
# 9419   https://ratings-images-prod.pulse.ea.com/FC25/...          0     186
#
#        weight  id_nationality  ... diff_positioning diff_reactions diff_sho  \
# 5616       81              38  ...                0             -2        0
# 14153      70              14  ...                0              0       -1
# 66         85              38  ...                0              0        0
# 9365       78              46  ...                0              0        0
# 1691       92              45  ...                0              0       -2
# ...       ...             ...  ...              ...            ...      ...
# 8045       77              54  ...                0              0        0
# 7141       56              17  ...                0              0        0
# 11907      71              52  ...                0              0        0
# 17337      74              95  ...                0              0        0
# 9419       76              34  ...                0              0        0
#
#       diff_shortPassing diff_shotPower diff_slidingTackle diff_sprintSpeed  \
# 5616                  0              0                  0               -4
# 14153                 0             -1                  0               -2
# 66                    3              0                  0                0
# 9365                  0              0                  0                0
# 1691                  0             -1                  0                0
# ...                 ...            ...                ...              ...
# 8045                  0              0                  0                0
# 7141                  0              0                  0                0
# 11907                 0              0                  0                0
# 17337                 0              0                  0                0
# 9419                  0              0                  0                0
#
#        diff_standingTackle diff_vision diff_volleys
# 5616                     0           0            0
# 14153                    0          -4            0
# 66                       0           2            0
# 9365                     0           0            0
# 1691                     0           0            0
# ...                    ...         ...          ...
# 8045                     0           0            0
# 7141                     0           0            0
# 11907                    0           0            0
# 17337                    0           0            0
# 9419                     0           0            0
#
# [17370 rows x 105 columns]
